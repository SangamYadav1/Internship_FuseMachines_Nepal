# %% [markdown]
# **Matplot Lib**
#
# *Matplot lib is a plotting library for python programming language and its numerical extension numpy.*
# *It provides an Object - orinted API for embedding plot into applications using general purpose GUI toolkit like Tkinter , PyQt , Wxpython , GTK*

# %% [markdown]
# Create two arrays: x, y  and z where:
#
# x contains 12 evenly spaced numbers between 1 and 20
#
# y contains the values of x multiplied by 2 ie. 2*x
#
# z contains the squares of elements of x ie x**2

# %%
import numpy as np

# %%
x = np.linspace(1,20,12)
print(x)
print(len(x))
# Out:
# [ 1.          2.72727273  4.45454545  6.18181818  7.90909091  9.63636364
#  11.36363636 13.09090909 14.81818182 16.54545455 18.27272727 20.        ]
# 12

# %%
y = x*2
print(y)
print(len(y))
# Out:
# [ 2.          5.45454545  8.90909091 12.36363636 15.81818182 19.27272727
#  22.72727273 26.18181818 29.63636364 33.09090909 36.54545455 40.        ]
# 12

# %%
z = x**2
print(z)
print(len(z))
# Out:
# [  1.           7.43801653  19.84297521  38.21487603  62.55371901
#   92.85950413 129.1322314  171.37190083 219.5785124  273.75206612
#  333.89256198 400.        ]
# 12

# %%
#Plot y vs x, set the label of x-axis as ‘x’, the label of y-axis as ‘y’ and 
#the title of the plot as ‘y = 2x’. Increase the x axis range to (0, 25) and y axis range to (0, 450)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.xlabel('x' , fontsize = 20)
plt.ylabel('y' , fontsize = 20)
plt.title('y = 2x' , fontsize = 20)
plt.xlim([0,25])
plt.ylim([0,450])
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400., 450.]),
#  <a list of 10 Text major ticklabel objects>)

# %%
#Create a new plot and plot y vs x and z vs x in the same plot. Differentiate between the two  functions using legend.
plt.plot(x,y,label = 'x vs y')
plt.plot(x,z,label = 'x vs z')
plt.legend()

# %%
#Create a figure containing two subplots. Set the size of the figure to be 12X6. 
#In the first subplot, plot y vs x and in the second subplot, plot z vs y. Set the title and axis labels accordingly.

# %%
f = plt.figure(figsize=(12,6))
subplot1 = f.add_subplot(1,2,1)
subplot2 = f.add_subplot(1,2,2)
subplot1.plot(x,y)
subplot2.plot(z , y)

subplot1.set_xlabel('x' , fontsize = 15)
subplot1.set_ylabel('y' , fontsize = 15)
subplot1.set_title('x vs y' , fontsize = 15)

subplot2.set_xlabel('x' , fontsize = 15)
subplot2.set_ylabel('z' , fontsize = 15)
subplot2.set_title('x vs z' , fontsize = 15)
# Out:
# Text(0.5, 1.0, 'x vs z')

# %%
#Finally, redo all the above plots using seaborn which is a higher level plotting library.
#It creates more aesthetically pleasing charts than matplotlib.

# %%
import seaborn as sns

# %%
ax = sns.lineplot(x,y)
ax.set_xlabel("X ",fontsize=15)
ax.set_ylabel("Y ",fontsize=15)
ax.set(title = 'X vs Y')
ax.set_xlim([0,25])
ax.set_ylim([0,450])
# Out:
# (0.0, 450.0)

# %%
sns.lineplot(x,y,label = 'x vs y')
sns.lineplot(x,z,label = 'x vs z')
plt.legend()

# %%
f, axes = plt.subplots(1, 2)

f.set_figheight(10)
f.set_figwidth(20)


a = sns.lineplot(x,y, ax=axes[0])
b = sns.lineplot(x,z, ax=axes[1])

a.set_xlabel("X ",fontsize=15)
a.set_ylabel("Y ",fontsize=15)
a.set(title = 'X vs Y')
a.set_xlim([0,25])
a.set_ylim([0,450])

b.set_xlabel("X ",fontsize=15)
b.set_ylabel("Z ",fontsize=15)
b.set(title = 'X vs Z')
b.set_xlim([0,25])
b.set_ylim([0,450])
# Out:
# (0.0, 450.0)

# %% [markdown]
# Create 3 arrays:
#
# x1 = [5,7,8,7,2,17,2,9,4,11,12,9,6]
#
# x2 = [99,86,87,88,111,86,103,87,94,78,77,85,86]
#
# y = [0, 1, 1, 0, 0, 1, 0, 0, 1, 0, 0, 1, 1]

# %%
x1 = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
x2 = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
y = np.array([0, 1, 1, 0, 0, 1, 0, 0, 1, 0, 0, 1, 1])
y = y.tolist()

# %%
print(x1)
print(x2)
print(y)
# Out:
# [ 5  7  8  7  2 17  2  9  4 11 12  9  6]
# [ 99  86  87  88 111  86 103  87  94  78  77  85  86]
# [0, 1, 1, 0, 0, 1, 0, 0, 1, 0, 0, 1, 1]

# %%
#Plot the scatterplot of x1 and x2. Color the points in the scatterplot according to their values in 
#y: blue for 0 and red for 1. For example, color the point (5, 99) blue as the corresponding y value is 0 and
#the point (7, 86) red as the corresponding y value is 1.

# %%
def pltcolor(lst):
    cols=[]
    for l in lst:
        if l==0:
            cols.append('blue')
        else:
            cols.append('red')
    return cols
cols=pltcolor(y)

plt.scatter(x1,x2 , c = cols)

# %% [markdown]
# #Plot a bar plot of the ‘outcome’ variable. Is the dataset balanced or unbalanced?
# #Try to explore the consequences of having such a dataset.

# %%
import pandas as pd

# %%
data = pd.read_csv("pima_diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = data.iloc[:,4]
print(len(x))
# Out:
# 768

# %%
y = data.iloc[:,-1]

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 768 artists>

# %%
print(len(y))
# Out:
# 768

# %%
y_list = list(y)
print("lenght of y: " , len(y_list))
print("length of y_containing 0: ", y_list.count(0))
print("length of y_containig 1:" , y_list.count(1))
# Out:
# lenght of y:  768
# length of y_containing 0:  500
# length of y_containig 1: 268

# %% [markdown]
# **The dataset is unbalanced because the values in the outcome have more  0 values then 1. This means there is more value which  leads to non diabities and less value which leads to diabities. The consiquences of unbalanced data set is that the model will get trained more in one of the outcome then another one which may lead to error while predcting. **

# %%
#Create a figure containing 8 subplots arranged in (2, 4) grid.
#Plot the histograms of the 8 features (all the columns except the outcome) present in the dataset.
#Identify the features having normal distribution and skewed distributions.

# %%
fig, axs = plt.subplots(2, 4)
fig.set_figheight(15)
fig.set_figwidth(30)

# feature1
axs[0, 0].hist(data.iloc[:,0])
axs[0, 0].set_title('feature1')



# feature2
axs[0, 1].hist(data.iloc[:,1])
axs[0, 1].set_title('feature2')



# feture3
axs[0, 2].hist(data.iloc[:,2])
axs[0, 2].set_title('feature3')



# feature4
axs[0, 3].hist(data.iloc[:,3])
axs[0, 3].set_title('faeture 4')



# feature 5
axs[1, 0].hist(data.iloc[:,4])
axs[1, 0].set_title('feature 5')



# feature 6
axs[1, 1].hist(data.iloc[:,5])
axs[1, 1].set_title('feature 6')



# feature 7
axs[1, 2].hist(data.iloc[:,6])
axs[1, 2].set_title('feature 7')

# feature 8
axs[1, 3].hist(data.iloc[:,7])
axs[1, 3].set_title('feature 8')


#If the histogram is skewed right, the mean is greater than the median.
#If the histogram is close to symmetric, then the mean and median are close to each other.
#If the histogram is skewed left, the mean is less than the median.
# Out:
# Text(0.5, 1.0, 'feature 8')

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print(data['Pregnancies'].mean())
print(data['Pregnancies'].median())
print("skewed")
# Out:
# 3.8450520833333335
# 3.0
# skewed

# %%
print(data['Glucose'].mean())
print(data['Glucose'].median())
print("skewed")
# Out:
# 120.89453125
# 117.0
# skewed

# %%
print(data['BloodPressure'].mean())
print(data['BloodPressure'].median())
print("skewed")
# Out:
# 69.10546875
# 72.0
# skewed

# %%
print(data['SkinThickness'].mean())
print(data['SkinThickness'].median())
print("skewed")
# Out:
# 20.536458333333332
# 23.0
# skewed

# %%
print(data['Insulin'].mean())
print(data['Insulin'].median())
print("skewed ")
# Out:
# 79.79947916666667
# 30.5
# skewed

# %%
print(data['BMI'].mean())
print(data['BMI'].median())
print("skewed")
# Out:
# 31.992578124999977
# 32.0
# skewed

# %%
print(data['DiabetesPedigreeFunction'].mean())
print(data['DiabetesPedigreeFunction'].median())
print("skewed")
# Out:
# 0.4718763020833327
# 0.3725
# skewed

# %%
print(data['Age'].mean())
print(data['Age'].median())
print("skewed")
# Out:
# 33.240885416666664
# 29.0
# skewed

# %%
#Create a figure containing 8 subplots arranged in (4, 2) grid.
#Plot the boxplot for each of the features in each of the subplots.
#Outliers are a set of observations that vary significantly from the other observations. 
#Which feature do you think has the most outliers? And Why?

# %%
fig, axs = plt.subplots(4, 2)
fig.set_figheight(15)
fig.set_figwidth(15)

# feature1
axs[0, 0].boxplot(data.iloc[:,0])
axs[0, 0].set_title('feature1')



# feature2
axs[0, 1].boxplot(data.iloc[:,1])
axs[0, 1].set_title('feature2')



# feture3
axs[1, 0].boxplot(data.iloc[:,2])
axs[1, 0].set_title('feature3')



# feature4
axs[1, 1].boxplot(data.iloc[:,3])
axs[1, 1].set_title('faeture 4')



# feature 5
axs[2, 0].boxplot(data.iloc[:,4])
axs[2, 0].set_title('feature 5')



# feature 6
axs[2, 1].boxplot(data.iloc[:,5])
axs[2, 1].set_title('feature 6')



# feature 7
axs[3, 0].boxplot(data.iloc[:,6])
axs[3, 0].set_title('feature 7')

# feature 8
axs[3, 1].boxplot(data.iloc[:,7])
axs[3, 1].set_title('feature 8')
# Out:
# Text(0.5, 1.0, 'feature 8')

# %% [markdown]
# **feature seven and feature 5 has more outliers compare to others as shown in the image. This is because:
# they have more data point compare which is loacted outside wishkers. **

# %%
#A correlation matrix represents how much the features are correlated to each other. 
#You can compute the correlation matrix of a dataframe using the dataframe.corr() method. 
#Use matplotlib.pyplot.matshow to plot the correlation matrix in matplotlib. 
#Also, you can use the matplotlib.pyplot.colorbar() to better explain your correlation matrix.

# %%
#this shows which data is more related to outcome and this is recommended during feature scaling to select
#important features in regression data set.(supervised learning)
data.corr().Outcome
# Out:
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
plt.matshow(data.corr())

# %%
import matplotlib.colors as colors

cdict = {'red':  ((0.0, 0.0, 0.0),   # no red at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.8, 0.8)),  # set to 0.8 so its not too bright at 1

        'green': ((0.0, 0.8, 0.8),   # set to 0.8 so its not too bright at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.0, 0.0)),  # no green at 1

        'blue':  ((0.0, 0.0, 0.0),   # no blue at 0
                  (0.5, 1.0, 1.0),   # all channels set to 1.0 at 0.5 to create white
                  (1.0, 0.0, 0.0))   # no blue at 1
       }

GnRd = colors.LinearSegmentedColormap('GnRd', cdict)
cor = plt.matshow(data, interpolation='nearest', cmap=GnRd, vmin=-1, vmax=1 ,alpha=1, aspect='auto' )
fig.colorbar(cor, ticks=[-1,0,1], shrink=0.8)

# %%
sns.__version__
# Out:
# '0.10.1'

# %%
dir(__builtin__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
import keyword 
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
